# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
def array(x):
    return x
def parse_list_col(x):
    return eval(x)[0]
def mean_list_col(x):
    return pd.DataFrame(x.values.tolist()).apply("mean", axis = 0).values.tolist()
def std_list_col(x):
    x =  pd.DataFrame(x.values.tolist()).apply("std", axis = 0).values.tolist()
    # print(x)
    return x
def upper_conf_list_col(x):
    mean = mean_list_col(x)
    std = std_list_col(x)
    return (np.array(mean) + 1.96 * np.array(std)).tolist()
def lower_conf_list_col(x):
    mean = mean_list_col(x)
    std = std_list_col(x)
    return (np.array(mean) - 1.96 * np.array(std)).tolist()
    
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
df = pd.read_csv("../20201029162623-summary.csv")
df["fprs"] = df["fprs"].apply(parse_list_col)
df["tprs"] = df["tprs"].apply(parse_list_col)

# %%
df.head()
# std_list_col(df["fprs"])
# Out:
#    Unnamed: 0                                               fprs  \
# 0           0  [0.0, 0.00980392, 0.00980392, 0.02941176, 0.02...
# 1           1  [0.0, 0.00980392, 0.00980392, 0.02941176, 0.02...
# 2           2  [0.0, 0.00980392, 0.00980392, 0.02941176, 0.02...
# 3           3  [0.0, 0.00980392, 0.00980392, 0.02941176, 0.02...
# 4           4  [0.0, 0.00980392, 0.00980392, 0.02941176, 0.02...
#
#                                                 tprs  roc_auc_scores  \
# 0  [0.0, 0.0, 0.00943396, 0.00943396, 0.05660377,...        0.584721
# 1  [0.0, 0.0, 0.00943396, 0.00943396, 0.05660377,...        0.505457
# 2  [0.0, 0.0, 0.00943396, 0.00943396, 0.05660377,...        0.500231
# 3  [0.0, 0.0, 0.00943396, 0.00943396, 0.05660377,...        0.500000
# 4  [0.0, 0.0, 0.00943396, 0.00943396, 0.05660377,...        0.499769
#
#    f1_scores opt_func                    loss_func  hidden_layer_size  \
# 0   0.675159      SGD  kullback_leibler_divergence                  1
# 1   0.675159      SGD  kullback_leibler_divergence                  1
# 2   0.675159      SGD  kullback_leibler_divergence                  1
# 3   0.675159      SGD  kullback_leibler_divergence                  1
# 4   0.675159      SGD  kullback_leibler_divergence                  1
#
#    layers_length
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
summary_df = df.groupby(["opt_func","loss_func","hidden_layer_size","layers_length"]).agg(
    mean_roc_auc_scores = ("roc_auc_scores","mean"),
    std_roc_auc_scores  = ("roc_auc_scores","std"),
    upper_conf_roc_auc_scores  = ("roc_auc_scores", lambda x: np.mean(x) + np.std(x)*1.96),
    lower_conf_roc_auc_scores  = ("roc_auc_scores", lambda x: np.mean(x) - np.std(x)*1.96),
    mean_f1_scores      = ("f1_scores","mean"),
    std_f1_scores       = ("f1_scores","std"),
    upper_conf_f1_scores  = ("roc_auc_scores", lambda x: np.mean(x) + np.std(x)*1.96),
    lower_conf_f1_scores  = ("roc_auc_scores", lambda x: np.mean(x) - np.std(x)*1.96),
    mean_fprs = ("fprs", mean_list_col),
    std_fprs = ("fprs", std_list_col),
    upper_conf_fprs = ("fprs", upper_conf_list_col),
    lower_conf_fprs = ("fprs", lower_conf_list_col),
    mean_tprs = ("tprs", mean_list_col),
    std_tprs = ("tprs", std_list_col),
    upper_conf_tprs = ("tprs", upper_conf_list_col),
    lower_conf_tprs = ("tprs", lower_conf_list_col),
).reset_index()
# print(summary_df)

# %%
summary_df_loss =  df.groupby(["loss_func"]).agg(
    mean_roc_auc_scores = ("roc_auc_scores","mean"),
    std_roc_auc_scores  = ("roc_auc_scores","std"),
    upper_conf_roc_auc_scores  = ("roc_auc_scores", lambda x: np.mean(x) + np.std(x)*1.96),
    lower_conf_roc_auc_scores  = ("roc_auc_scores", lambda x: np.mean(x) - np.std(x)*1.96),
    mean_f1_scores      = ("f1_scores","mean"),
    std_f1_scores       = ("f1_scores","std"),
    upper_conf_f1_scores  = ("roc_auc_scores", lambda x: np.mean(x) + np.std(x)*1.96),
    lower_conf_f1_scores  = ("roc_auc_scores", lambda x: np.mean(x) - np.std(x)*1.96),
    mean_fprs = ("fprs", mean_list_col),
    std_fprs = ("fprs", std_list_col),
    upper_conf_fprs = ("fprs", upper_conf_list_col),
    lower_conf_fprs = ("fprs", lower_conf_list_col),
    mean_tprs = ("tprs", mean_list_col),
    std_tprs = ("tprs", std_list_col),
    upper_conf_tprs = ("tprs", upper_conf_list_col),
    lower_conf_tprs = ("tprs", lower_conf_list_col),
).reset_index()
summary_df_loss.head()
summary_df_opt =  df.groupby(["opt_func"]).agg(
    mean_roc_auc_scores = ("roc_auc_scores","mean"),
    std_roc_auc_scores  = ("roc_auc_scores","std"),
    upper_conf_roc_auc_scores  = ("roc_auc_scores", lambda x: np.mean(x) + np.std(x)*1.96),
    lower_conf_roc_auc_scores  = ("roc_auc_scores", lambda x: np.mean(x) - np.std(x)*1.96),
    mean_f1_scores      = ("f1_scores","mean"),
    std_f1_scores       = ("f1_scores","std"),
    upper_conf_f1_scores  = ("roc_auc_scores", lambda x: np.mean(x) + np.std(x)*1.96),
    lower_conf_f1_scores  = ("roc_auc_scores", lambda x: np.mean(x) - np.std(x)*1.96),
    mean_fprs = ("fprs", mean_list_col),
    std_fprs = ("fprs", std_list_col),
    upper_conf_fprs = ("fprs", upper_conf_list_col),
    lower_conf_fprs = ("fprs", lower_conf_list_col),
    mean_tprs = ("tprs", mean_list_col),
    std_tprs = ("tprs", std_list_col),
    upper_conf_tprs = ("tprs", upper_conf_list_col),
    lower_conf_tprs = ("tprs", lower_conf_list_col),
).reset_index()
summary_df_opt.head()
summary_df_layer_l =  df.groupby(["layers_length"]).agg(
    mean_roc_auc_scores = ("roc_auc_scores","mean"),
    std_roc_auc_scores  = ("roc_auc_scores","std"),
    upper_conf_roc_auc_scores  = ("roc_auc_scores", lambda x: np.mean(x) + np.std(x)*1.96),
    lower_conf_roc_auc_scores  = ("roc_auc_scores", lambda x: np.mean(x) - np.std(x)*1.96),
    mean_f1_scores      = ("f1_scores","mean"),
    std_f1_scores       = ("f1_scores","std"),
    upper_conf_f1_scores  = ("roc_auc_scores", lambda x: np.mean(x) + np.std(x)*1.96),
    lower_conf_f1_scores  = ("roc_auc_scores", lambda x: np.mean(x) - np.std(x)*1.96),
    mean_fprs = ("fprs", mean_list_col),
    std_fprs = ("fprs", std_list_col),
    upper_conf_fprs = ("fprs", upper_conf_list_col),
    lower_conf_fprs = ("fprs", lower_conf_list_col),
    mean_tprs = ("tprs", mean_list_col),
    std_tprs = ("tprs", std_list_col),
    upper_conf_tprs = ("tprs", upper_conf_list_col),
    lower_conf_tprs = ("tprs", lower_conf_list_col),
).reset_index()
summary_df_layer_l.head()
summary_df_layer_s =  df.groupby(["hidden_layer_size"]).agg(
    mean_roc_auc_scores = ("roc_auc_scores","mean"),
    std_roc_auc_scores  = ("roc_auc_scores","std"),
    upper_conf_roc_auc_scores  = ("roc_auc_scores", lambda x: np.mean(x) + np.std(x)*1.96),
    lower_conf_roc_auc_scores  = ("roc_auc_scores", lambda x: np.mean(x) - np.std(x)*1.96),
    mean_f1_scores      = ("f1_scores","mean"),
    std_f1_scores       = ("f1_scores","std"),
    upper_conf_f1_scores  = ("roc_auc_scores", lambda x: np.mean(x) + np.std(x)*1.96),
    lower_conf_f1_scores  = ("roc_auc_scores", lambda x: np.mean(x) - np.std(x)*1.96),
    mean_fprs = ("fprs", mean_list_col),
    std_fprs = ("fprs", std_list_col),
    upper_conf_fprs = ("fprs", upper_conf_list_col),
    lower_conf_fprs = ("fprs", lower_conf_list_col),
    mean_tprs = ("tprs", mean_list_col),
    std_tprs = ("tprs", std_list_col),
    upper_conf_tprs = ("tprs", upper_conf_list_col),
    lower_conf_tprs = ("tprs", lower_conf_list_col),
).reset_index()
summary_df_layer_s.head()
# Out:
#    hidden_layer_size  mean_roc_auc_scores  std_roc_auc_scores  \
# 0                  1             0.500260            0.005259
# 1                  5             0.539125            0.091043
# 2                 10             0.545685            0.085734
# 3                 50             0.554600            0.086636
#
#    upper_conf_roc_auc_scores  lower_conf_roc_auc_scores  mean_f1_scores  \
# 0                   0.510548                   0.489973        0.225053
# 1                   0.717238                   0.361012        0.516076
# 2                   0.713412                   0.377958        0.511636
# 3                   0.724091                   0.385109        0.544040
#
#    std_f1_scores  upper_conf_f1_scores  lower_conf_f1_scores  \
# 0       0.318864              0.510548              0.489973
# 1       0.252081              0.717238              0.361012
# 2       0.277086              0.713412              0.377958
# 3       0.243341              0.724091              0.385109
#
#                                            mean_fprs  \
# 0  [0.0, 0.9633260711111111, 0.009803919999999999...
# 1  [0.0, 0.19535221444444498, 0.22285067807692285...
# 2  [0.0, 0.2559912844444445, 0.11229946318181816,...
# 3  [0.0, 0.17465504629629644, 0.15176470480000018...
#
#                                             std_fprs  \
# 0  [0.0, 0.18734834225739772, 1.828559098217032e-...
# 1  [0.0, 0.3386160543438579, 0.3605183171756997, ...
# 2  [0.0, 0.4242577466108198, 0.2802052846134307, ...
# 3  [0.0, 0.3518850680208632, 0.3124471950995607, ...
#
#                                      upper_conf_fprs  \
# 0  [0.0, 1.3305288219356106, 0.009803920000000002...
# 1  [0.0, 0.8590396809584064, 0.9294665797412942, ...
# 2  [0.0, 1.0875364678016513, 0.6615018210241423, ...
# 3  [0.0, 0.8643497796171884, 0.7641612071951391, ...
#
#                                      lower_conf_fprs  \
# 0  [0.0, 0.5961233202866116, 0.009803919999999995...
# 1  [0.0, -0.46833525206951654, -0.483765223587448...
# 2  [0.0, -0.5755538989127622, -0.436902894660506,...
# 3  [0.0, -0.5150396870245955, -0.4606317975951388...
#
#                                            mean_tprs  \
# 0  [0.0, 0.9629629629629629, 0.009433960000000002...
# 1  [0.0, 0.21977637925925947, 0.21770682038461567...
# 2  [0.0, 0.26135569444444434, 0.10205831772727278...
# 3  [0.0, 0.18413696629629608, 0.16339622479999985...
#
#                                             std_tprs  \
# 0  [0.0, 0.18920327603942325, 1.828559098217032e-...
# 1  [0.0, 0.36913978128923175, 0.38949242337816237...
# 2  [0.0, 0.43386020385240487, 0.2849027846187604,...
# 3  [0.0, 0.3623238611944702, 0.3325559509207513, ...
#
#                                      upper_conf_tprs  \
# 0  [0.0, 1.3338013840002325, 0.009433960000000005...
# 1  [0.0, 0.9432903505861536, 0.9811119702058139, ...
# 2  [0.0, 1.111721693995158, 0.6604677755800432, 0...
# 3  [0.0, 0.8942917342374576, 0.8152058886046724, ...
#
#                                      lower_conf_tprs
# 0  [0.0, 0.5921245419256933, 0.009433959999999998...
# 1  [0.0, -0.5037375920676348, -0.5456983294365826...
# 2  [0.0, -0.5890103051062692, -0.4563511401254976...
# 3  [0.0, -0.5260178016448654, -0.4884134390046727...

# %%
# %matplotlib inline
plt.bar(summary_df_loss.loss_func, summary_df_loss.mean_roc_auc_scores, yerr = summary_df_loss.std_roc_auc_scores, capsize = 6)
# plt.show()
plt.savefig("loss_func_bar.png", dpi = 1000)
plt.clf()
plt.bar(summary_df_opt.opt_func, summary_df_opt.mean_roc_auc_scores, yerr = summary_df_opt.std_roc_auc_scores, capsize = 6)
# plt.show()
plt.savefig("opt_func_bar.png", dpi = 1000)
plt.clf()
plt.bar(summary_df_layer_s.hidden_layer_size.apply(str), summary_df_layer_s.mean_roc_auc_scores, yerr = summary_df_layer_s.std_roc_auc_scores, capsize = 6)
# plt.show()
plt.savefig("hidden_layer_size_bar.png", dpi = 1000)
plt.clf()
plt.bar(summary_df_layer_l.layers_length.apply(str), summary_df_layer_l.mean_roc_auc_scores, yerr = summary_df_layer_l.std_roc_auc_scores, capsize = 6)
# plt.show()
plt.savefig("layers_length.png", dpi = 1000)
plt.clf()

# %%
    
for x in summary_df.layers_length.unique().tolist():
    plt.clf()
    plt.plot([0, 1], [0, 1], linestyle="--", label="")
    for _, row in summary_df[summary_df["layers_length"] == x].iterrows():
#         print(row["hidden_layer_size"])
#         print(row["mean_fprs"])
#         print(row["mean_tprs"])
        fpr = row["mean_fprs"]
        tpr = row["mean_tprs"]
#         print(type(fpr))
        h_size = row["hidden_layer_size"]
        lbl=f"{h_size} Hidden Layer Size"
#         print(lbl)
        plt.plot(
            fpr,
            tpr,
            linestyle="-",
            label=lbl
    )
    tlt = f"ROC of {x} layer NN"
    plt.title(tlt)
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.legend()
    plt.show()

# %%
for x in summary_df.opt_func.unique().tolist():
    for y in summary_df.loss_func.unique().tolist():
        for z in summary_df.layers_length.unique().tolist():
#           plt.clf()
            plt.plot([0, 1], [0, 1], linestyle="--", label="")
            for _, row in summary_df[(summary_df["opt_func"] == x) & (summary_df["loss_func"] == y) & (summary_df["layers_length"] == z)].iterrows():
#             print(row)
#             print(row["hidden_layer_size"])
#             print(row["mean_fprs"])
#                 print(row["mean_tprs"])
                fpr = row["mean_fprs"]
                tpr = row["mean_tprs"]
#             print(type(fpr))
                h_size = row["hidden_layer_size"]
#                 l_layers = row["layers_length"]
                lbl=f"{h_size} Hidden Layer Size"
#             print(lbl)
                plt.plot(
                fpr,
                tpr,
                linestyle="-",
                label=lbl
                )
#                 print(row["lower_conf_tprs"], row["upper_conf_tprs"])

            tlt = f"Mean ROC of {x} opt, {y} loss,{z} layer length"
            plt.title(tlt)
            plt.xlabel("False Positive Rate")
            plt.ylabel("True Positive Rate")
            plt.legend()
            plt.savefig(f"{tlt}.png", dpi = 1000)
            plt.show()

# %%
for x in summary_df.opt_func.unique().tolist():
    for y in summary_df.loss_func.unique().tolist():
        for z in summary_df.hidden_layer_size.unique().tolist():
#           plt.clf()
            plt.plot([0, 1], [0, 1], linestyle="--", label="")
            for _, row in summary_df[(summary_df["opt_func"] == x) & (summary_df["loss_func"] == y) & (summary_df["hidden_layer_size"] == z)].iterrows():
#             print(row)
#             print(row["hidden_layer_size"])
#             print(row["mean_fprs"])
#                 print(row["mean_tprs"])
                fpr = row["mean_fprs"]
                tpr = row["mean_tprs"]
#             print(type(fpr))
                h_size = row["layers_length"]
#                 l_layers = row["layers_length"]
                lbl=f"{h_size} Layers Length"
#             print(lbl)
                plt.plot(
                fpr,
                tpr,
                linestyle="-",
                label=lbl
                )
#                 print(row["lower_conf_tprs"], row["upper_conf_tprs"])

            tlt = f"Mean ROC of {x} opt, {y} loss,{z} hidden layer size"
            plt.title(tlt)
            plt.xlabel("False Positive Rate")
            plt.ylabel("True Positive Rate")
            plt.legend()
            plt.savefig(f"{tlt}.png", dpi = 1000)
            plt.show()

# %%
plt.plot([0, 1], [0, 1], linestyle="--", label="")
for _,row in summary_df_layer_l.iterrows():
    fpr = row["mean_fprs"]
    tpr = row["mean_tprs"]
#   print(type(fpr))
    h_size = row["layers_length"]
#   l_layers = row["layers_length"]
    lbl=f"{h_size} Layers Length"
#    print(lbl)
    plt.plot(
                fpr,
                tpr,
                linestyle="-",
                label=lbl
     )
#                 print(row["lower_conf_tprs"], row["upper_conf_tprs"])

    tlt = f"Mean ROC of NN depths"
plt.title(tlt)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.savefig(f"{tlt}.png", dpi = 1000)
plt.show()

# %%
plt.plot([0, 1], [0, 1], linestyle="--", label="")
for _,row in summary_df_layer_s.iterrows():
    fpr = row["mean_fprs"]
    tpr = row["mean_tprs"]
#   print(type(fpr))
    h_size = row["hidden_layer_size"]
#   l_layers = row["layers_length"]
    lbl=f"{h_size} hidden_layer_size"
#    print(lbl)
    plt.plot(
                fpr,
                tpr,
                linestyle="-",
                label=lbl
     )
#                 print(row["lower_conf_tprs"], row["upper_conf_tprs"])

    tlt = f"Mean ROC of Layer Size"
plt.title(tlt)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
#     plt.savefig(f"{tlt}.png", dpi = 1000)
plt.show()

# %%
plt.plot([0, 1], [0, 1], linestyle="--", label="")
for _,row in summary_df_loss.iterrows():
    fpr = row["mean_fprs"]
    tpr = row["mean_tprs"]
#   print(type(fpr))
    h_size = row["loss_func"]
#   l_layers = row["layers_length"]
    lbl=f"{h_size} loss_func"
#    print(lbl)
    plt.plot(
                fpr,
                tpr,
                linestyle="-",
                label=lbl
     )
#                 print(row["lower_conf_tprs"], row["upper_conf_tprs"])

    tlt = f"Mean ROC of Loss Function"
plt.title(tlt)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
#     plt.savefig(f"{tlt}.png", dpi = 1000)
plt.show()

# %%
# %matplotlib inline
plt.bar(summary_df_loss.loss_func, summary_df_loss.mean_f1_scores, yerr = summary_df_loss.std_f1_scores, capsize = 6)
plt.show()
# plt.savefig("loss_func_bar.png", dpi = 1000)
plt.clf()
plt.bar(summary_df_opt.opt_func, summary_df_opt.mean_f1_scores, yerr = summary_df_opt.std_f1_scores, capsize = 6)
plt.show()
# plt.savefig("opt_func_bar.png", dpi = 1000)
plt.clf()
plt.bar(summary_df_layer_s.hidden_layer_size.apply(str), summary_df_layer_s.mean_f1_scores, yerr = summary_df_layer_s.std_f1_scores, capsize = 6)
plt.show()
# plt.savefig("hidden_layer_size_bar.png", dpi = 1000)
plt.clf()
plt.bar(summary_df_layer_l.layers_length.apply(str), summary_df_layer_l.mean_f1_scores, yerr = summary_df_layer_l.std_f1_scores, capsize = 6)
plt.show()
# plt.savefig("layers_length.png", dpi = 1000)
# plt.clf()

# %%
sub_par_df = summary_df[summary_df["mean_roc_auc_scores"] < 0.5]
# sub_par_df.apply(pd.value_counts)
sub_par_df[["opt_func"]].apply(pd.value_counts).plot(kind = "bar")
plt.show()
sub_par_df[["loss_func"]].apply(pd.value_counts).plot(kind = "bar")
plt.show()
sub_par_df[["hidden_layer_size"]].apply(pd.value_counts).plot(kind = "bar")
plt.show()
sub_par_df[["layers_length"]].apply(pd.value_counts).plot(kind = "bar")
plt.show()

# %%
summary_df_model = df[["roc_auc_scores", "layers_length", "hidden_layer_size", "opt_func", "loss_func"]]
mod = smf.ols(formula='roc_auc_scores ~ C(layers_length) + C(hidden_layer_size) + loss_func + opt_func', data=summary_df_model)
res = mod.fit()
print(res.summary().as_latex())
fig = sm.graphics.plot_partregress_grid(res)
fig.tight_layout(pad=1.0)
res.summary()
# Out:
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}                              & roc\_auc\_scores & \textbf{  R-squared:         } &     0.331   \\
# \textbf{Model:}                                      &       OLS        & \textbf{  Adj. R-squared:    } &     0.325   \\
# \textbf{Method:}                                     &  Least Squares   & \textbf{  F-statistic:       } &     58.80   \\
# \textbf{Date:}                                       & Fri, 30 Oct 2020 & \textbf{  Prob (F-statistic):} &  2.77e-87   \\
# \textbf{Time:}                                       &     18:04:11     & \textbf{  Log-Likelihood:    } &    1429.3   \\
# \textbf{No. Observations:}                           &        1080      & \textbf{  AIC:               } &    -2839.   \\
# \textbf{Df Residuals:}                               &        1070      & \textbf{  BIC:               } &    -2789.   \\
# \textbf{Df Model:}                                   &           9      & \textbf{                     } &             \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
#                                                      & \textbf{coef} & \textbf{std err} & \textbf{t} & \textbf{P$> |$t$|$} & \textbf{[0.025} & \textbf{0.975]}  \\
# \midrule
# \textbf{Intercept}                                   &       0.5789  &        0.006     &    92.955  &         0.000        &        0.567    &        0.591     \\
# \textbf{C(layers\_length)[T.2]}                      &      -0.0295  &        0.005     &    -6.121  &         0.000        &       -0.039    &       -0.020     \\
# \textbf{C(layers\_length)[T.5]}                      &      -0.0540  &        0.005     &   -11.198  &         0.000        &       -0.063    &       -0.045     \\
# \textbf{C(hidden\_layer\_size)[T.5]}                 &       0.0389  &        0.006     &     6.977  &         0.000        &        0.028    &        0.050     \\
# \textbf{C(hidden\_layer\_size)[T.10]}                &       0.0454  &        0.006     &     8.155  &         0.000        &        0.034    &        0.056     \\
# \textbf{C(hidden\_layer\_size)[T.50]}                &       0.0543  &        0.006     &     9.756  &         0.000        &        0.043    &        0.065     \\
# \textbf{loss\_func[T.hinge]}                         &      -0.0732  &        0.005     &   -15.184  &         0.000        &       -0.083    &       -0.064     \\
# \textbf{loss\_func[T.kullback\_leibler\_divergence]} &      -0.0346  &        0.005     &    -7.183  &         0.000        &       -0.044    &       -0.025     \\
# \textbf{opt\_func[T.RMSprop]}                        &      -0.0083  &        0.005     &    -1.716  &         0.087        &       -0.018    &        0.001     \\
# \textbf{opt\_func[T.SGD]}                            &      -0.0362  &        0.005     &    -7.495  &         0.000        &       -0.046    &       -0.027     \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lclc}
# \textbf{Omnibus:}       & 42.413 & \textbf{  Durbin-Watson:     } &    1.183  \\
# \textbf{Prob(Omnibus):} &  0.000 & \textbf{  Jarque-Bera (JB):  } &   46.843  \\
# \textbf{Skew:}          & -0.510 & \textbf{  Prob(JB):          } & 6.73e-11  \\
# \textbf{Kurtosis:}      &  2.980 & \textbf{  Cond. No.          } &     6.48  \\
# \bottomrule
# \end{tabular}
# %\caption{OLS Regression Results}
# \end{center}
#
# Notes: \newline
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         roc_auc_scores   R-squared:                       0.331
# Model:                            OLS   Adj. R-squared:                  0.325
# Method:                 Least Squares   F-statistic:                     58.80
# Date:                Fri, 30 Oct 2020   Prob (F-statistic):           2.77e-87
# Time:                        18:04:12   Log-Likelihood:                 1429.3
# No. Observations:                1080   AIC:                            -2839.
# Df Residuals:                    1070   BIC:                            -2789.
# Df Model:                           9
# Covariance Type:            nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# Intercept                                    0.5789      0.006     92.955      0.000       0.567       0.591
# C(layers_length)[T.2]                       -0.0295      0.005     -6.121      0.000      -0.039      -0.020
# C(layers_length)[T.5]                       -0.0540      0.005    -11.198      0.000      -0.063      -0.045
# C(hidden_layer_size)[T.5]                    0.0389      0.006      6.977      0.000       0.028       0.050
# C(hidden_layer_size)[T.10]                   0.0454      0.006      8.155      0.000       0.034       0.056
# C(hidden_layer_size)[T.50]                   0.0543      0.006      9.756      0.000       0.043       0.065
# loss_func[T.hinge]                          -0.0732      0.005    -15.184      0.000      -0.083      -0.064
# loss_func[T.kullback_leibler_divergence]    -0.0346      0.005     -7.183      0.000      -0.044      -0.025
# opt_func[T.RMSprop]                         -0.0083      0.005     -1.716      0.087      -0.018       0.001
# opt_func[T.SGD]                             -0.0362      0.005     -7.495      0.000      -0.046      -0.027
# ==============================================================================
# Omnibus:                       42.413   Durbin-Watson:                   1.183
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.843
# Skew:                          -0.510   Prob(JB):                     6.73e-11
# Kurtosis:                       2.980   Cond. No.                         6.48
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
np.corrcoef(df.roc_auc_scores, df.f1_scores)

summary_df_model = df[["f1_scores", "layers_length", "hidden_layer_size", "opt_func", "loss_func"]]
mod = smf.ols(formula='f1_scores ~ C(layers_length) + C(hidden_layer_size) + loss_func + opt_func', data=summary_df_model)
res = mod.fit()
print(res.summary().as_latex())
fig = sm.graphics.plot_partregress_grid(res)
fig.tight_layout(pad=1.0)
res.summary()
# Out:
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}                              &    f1\_scores    & \textbf{  R-squared:         } &     0.466   \\
# \textbf{Model:}                                      &       OLS        & \textbf{  Adj. R-squared:    } &     0.462   \\
# \textbf{Method:}                                     &  Least Squares   & \textbf{  F-statistic:       } &     103.9   \\
# \textbf{Date:}                                       & Fri, 30 Oct 2020 & \textbf{  Prob (F-statistic):} & 2.51e-139   \\
# \textbf{Time:}                                       &     20:39:24     & \textbf{  Log-Likelihood:    } &    95.570   \\
# \textbf{No. Observations:}                           &        1080      & \textbf{  AIC:               } &    -171.1   \\
# \textbf{Df Residuals:}                               &        1070      & \textbf{  BIC:               } &    -121.3   \\
# \textbf{Df Model:}                                   &           9      & \textbf{                     } &             \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
#                                                      & \textbf{coef} & \textbf{std err} & \textbf{t} & \textbf{P$> |$t$|$} & \textbf{[0.025} & \textbf{0.975]}  \\
# \midrule
# \textbf{Intercept}                                   &       0.2564  &        0.021     &    11.974  &         0.000        &        0.214    &        0.298     \\
# \textbf{C(layers\_length)[T.2]}                      &      -0.0850  &        0.017     &    -5.126  &         0.000        &       -0.118    &       -0.052     \\
# \textbf{C(layers\_length)[T.5]}                      &      -0.1026  &        0.017     &    -6.184  &         0.000        &       -0.135    &       -0.070     \\
# \textbf{C(hidden\_layer\_size)[T.5]}                 &       0.2910  &        0.019     &    15.196  &         0.000        &        0.253    &        0.329     \\
# \textbf{C(hidden\_layer\_size)[T.10]}                &       0.2866  &        0.019     &    14.965  &         0.000        &        0.249    &        0.324     \\
# \textbf{C(hidden\_layer\_size)[T.50]}                &       0.3190  &        0.019     &    16.657  &         0.000        &        0.281    &        0.357     \\
# \textbf{loss\_func[T.hinge]}                         &      -0.1099  &        0.017     &    -6.625  &         0.000        &       -0.142    &       -0.077     \\
# \textbf{loss\_func[T.kullback\_leibler\_divergence]} &       0.2564  &        0.017     &    15.462  &         0.000        &        0.224    &        0.289     \\
# \textbf{opt\_func[T.RMSprop]}                        &      -0.0070  &        0.017     &    -0.421  &         0.674        &       -0.040    &        0.026     \\
# \textbf{opt\_func[T.SGD]}                            &      -0.0459  &        0.017     &    -2.770  &         0.006        &       -0.078    &       -0.013     \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lclc}
# \textbf{Omnibus:}       & 31.678 & \textbf{  Durbin-Watson:     } &    1.408  \\
# \textbf{Prob(Omnibus):} &  0.000 & \textbf{  Jarque-Bera (JB):  } &   32.974  \\
# \textbf{Skew:}          & -0.409 & \textbf{  Prob(JB):          } & 6.91e-08  \\
# \textbf{Kurtosis:}      &  2.750 & \textbf{  Cond. No.          } &     6.48  \\
# \bottomrule
# \end{tabular}
# %\caption{OLS Regression Results}
# \end{center}
#
# Notes: \newline
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              f1_scores   R-squared:                       0.466
# Model:                            OLS   Adj. R-squared:                  0.462
# Method:                 Least Squares   F-statistic:                     103.9
# Date:                Fri, 30 Oct 2020   Prob (F-statistic):          2.51e-139
# Time:                        20:39:25   Log-Likelihood:                 95.570
# No. Observations:                1080   AIC:                            -171.1
# Df Residuals:                    1070   BIC:                            -121.3
# Df Model:                           9
# Covariance Type:            nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# Intercept                                    0.2564      0.021     11.974      0.000       0.214       0.298
# C(layers_length)[T.2]                       -0.0850      0.017     -5.126      0.000      -0.118      -0.052
# C(layers_length)[T.5]                       -0.1026      0.017     -6.184      0.000      -0.135      -0.070
# C(hidden_layer_size)[T.5]                    0.2910      0.019     15.196      0.000       0.253       0.329
# C(hidden_layer_size)[T.10]                   0.2866      0.019     14.965      0.000       0.249       0.324
# C(hidden_layer_size)[T.50]                   0.3190      0.019     16.657      0.000       0.281       0.357
# loss_func[T.hinge]                          -0.1099      0.017     -6.625      0.000      -0.142      -0.077
# loss_func[T.kullback_leibler_divergence]     0.2564      0.017     15.462      0.000       0.224       0.289
# opt_func[T.RMSprop]                         -0.0070      0.017     -0.421      0.674      -0.040       0.026
# opt_func[T.SGD]                             -0.0459      0.017     -2.770      0.006      -0.078      -0.013
# ==============================================================================
# Omnibus:                       31.678   Durbin-Watson:                   1.408
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.974
# Skew:                          -0.409   Prob(JB):                     6.91e-08
# Kurtosis:                       2.750   Cond. No.                         6.48
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
